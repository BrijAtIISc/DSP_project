# %% [markdown]
# # Data Preprocessing
# > Author: Chandan Rao (chandankuma4@iisc.ac.in)

# %%
import json
import torch
import pandas as pd
from datetime import datetime
from transformers import pipeline
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# %%
# Load the dataset
df = pd.read_csv('../Dataset/newsapi/raw/NewsDataset.csv')

# %%
# Extracting the name value from the source column
df['source'] = df['source'].apply(lambda x: eval(x)["name"] if isinstance(x, str) else x)

df['source']
# Out:
# 0                   Forbes
# 1                   Forbes
# 2                 Livemint
# 3             BusinessLine
# 4        Business Standard
#                ...
# 12142         BusinessLine
# 12143         BusinessLine
# 12144         BusinessLine
# 12145         BusinessLine
# 12146         BusinessLine
# Name: source, Length: 12147, dtype: object

# %%
# Converting 'publishedAt' to datetime and extracting the date and time
df['publishedAt'] = pd.to_datetime(df['publishedAt']).dt.tz_convert(None)

# %%
# Removing microseconds from the datetime
df['publishedAt'] = df['publishedAt'].dt.floor('s')

# %%
df.publishedAt.head()
# Out:
# 0   2024-10-22 16:00:08
# 1   2024-10-09 22:03:27
# 2   2024-10-11 05:50:52
# 3   2024-10-09 19:40:00
# 4   2024-10-14 13:41:19
# Name: publishedAt, dtype: datetime64[ns]

# %%
# Remove duplicate rows based on all columns
df.drop_duplicates(inplace=True)

# %%
# Retain only the source, author, title, description, publishedAt, url, and content columns
df_filtered = df[['source','author', 'title', 'description', 'publishedAt', 'url', 'content','search_query']]
df_filtered.head()
# Out:
#               source                                             author  \
# 0             Forbes  John Kang, Forbes Staff, \n John Kang, Forbes ...
# 1             Forbes  Gloria Haraito, Forbes Staff, \n Gloria Harait...
# 2           Livemint                                      George Skaria
# 3       BusinessLine                                                NaN
# 4  Business Standard                                     Dev Chatterjee
#
#                                                title  \
# 0  Hyundai Motor India Shares Slump As Trading Be...
# 1  What’s Driving The Son Of India’s Richest Woma...
# 2   Tata’s next challenge: Leadership void at Trusts
# 3                      Ratan Tata over the years - I
# 4  Tata Capital, Tata Motors Finance merger recei...
#
#                                          description         publishedAt  \
# 0  The South Korean car maker’s $3.3 billion shar... 2024-10-22 16:00:08
# 1  Amid India’s EV push, steel magnate Sajjan Jin... 2024-10-09 22:03:27
# 2  With Ratan Tata’s passing, the lack of a clear... 2024-10-11 05:50:52
# 3  Following the demise of Ratan Tata, here are s... 2024-10-09 19:40:00
# 4  Tata Capital-Tata Motors Finance Merger: Throu... 2024-10-14 13:41:19
#
#                                                  url  \
# 0  https://www.forbes.com/sites/johnkang/2024/10/...
# 1  https://www.forbes.com/sites/gloriaharaito/202...
# 2  https://www.livemint.com/opinion/ratan-tata-de...
# 3  https://www.thehindubusinessline.com/multimedi...
# 4  https://www.business-standard.com/companies/ne...
#
#                                              content            search_query
# 0  Hyundai Motor India managing director Unsoo Ki...  Tata Motors March 2024
# 1  Sajjan (left) and Parth Jindal.\nJSW Group\nTh...  Tata Motors March 2024
# 2  With the passing of Ratan Naval Tata (1937-202...  Tata Motors March 2024
# 3  Following the demise of Ratan Tata, here are s...  Tata Motors March 2024
# 4  Through this merger, Tata Capital aims to attr...  Tata Motors March 2024

# %%
# Rename the search_query field to companyName and author to authors
df_filtered.rename(columns={'search_query': 'companyName','author':'authors', 'content':'summary'}, inplace=True)
# Out:
# /var/folders/3z/qsmfql2d31b5c7fv1rkpfq640000gn/T/ipykernel_5855/3486304602.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered.rename(columns={'search_query': 'companyName','author':'authors', 'content':'summary'}, inplace=True)

# %%
df_filtered.head()
# Out:
#               source                                            authors  \
# 0             Forbes  John Kang, Forbes Staff, \n John Kang, Forbes ...
# 1             Forbes  Gloria Haraito, Forbes Staff, \n Gloria Harait...
# 2           Livemint                                      George Skaria
# 3       BusinessLine                                                NaN
# 4  Business Standard                                     Dev Chatterjee
#
#                                                title  \
# 0  Hyundai Motor India Shares Slump As Trading Be...
# 1  What’s Driving The Son Of India’s Richest Woma...
# 2   Tata’s next challenge: Leadership void at Trusts
# 3                      Ratan Tata over the years - I
# 4  Tata Capital, Tata Motors Finance merger recei...
#
#                                          description         publishedAt  \
# 0  The South Korean car maker’s $3.3 billion shar... 2024-10-22 16:00:08
# 1  Amid India’s EV push, steel magnate Sajjan Jin... 2024-10-09 22:03:27
# 2  With Ratan Tata’s passing, the lack of a clear... 2024-10-11 05:50:52
# 3  Following the demise of Ratan Tata, here are s... 2024-10-09 19:40:00
# 4  Tata Capital-Tata Motors Finance Merger: Throu... 2024-10-14 13:41:19
#
#                                                  url  \
# 0  https://www.forbes.com/sites/johnkang/2024/10/...
# 1  https://www.forbes.com/sites/gloriaharaito/202...
# 2  https://www.livemint.com/opinion/ratan-tata-de...
# 3  https://www.thehindubusinessline.com/multimedi...
# 4  https://www.business-standard.com/companies/ne...
#
#                                              summary             companyName
# 0  Hyundai Motor India managing director Unsoo Ki...  Tata Motors March 2024
# 1  Sajjan (left) and Parth Jindal.\nJSW Group\nTh...  Tata Motors March 2024
# 2  With the passing of Ratan Naval Tata (1937-202...  Tata Motors March 2024
# 3  Following the demise of Ratan Tata, here are s...  Tata Motors March 2024
# 4  Through this merger, Tata Capital aims to attr...  Tata Motors March 2024

# %%
# Remove the last two words from the companyName field values
df_filtered.loc[:, 'companyName'] = df_filtered['companyName'].apply(lambda x: ' '.join(x.split()[:-2]))

# %%
df_filtered.head()
# Out:
#               source                                            authors  \
# 0             Forbes  John Kang, Forbes Staff, \n John Kang, Forbes ...
# 1             Forbes  Gloria Haraito, Forbes Staff, \n Gloria Harait...
# 2           Livemint                                      George Skaria
# 3       BusinessLine                                                NaN
# 4  Business Standard                                     Dev Chatterjee
#
#                                                title  \
# 0  Hyundai Motor India Shares Slump As Trading Be...
# 1  What’s Driving The Son Of India’s Richest Woma...
# 2   Tata’s next challenge: Leadership void at Trusts
# 3                      Ratan Tata over the years - I
# 4  Tata Capital, Tata Motors Finance merger recei...
#
#                                          description         publishedAt  \
# 0  The South Korean car maker’s $3.3 billion shar... 2024-10-22 16:00:08
# 1  Amid India’s EV push, steel magnate Sajjan Jin... 2024-10-09 22:03:27
# 2  With Ratan Tata’s passing, the lack of a clear... 2024-10-11 05:50:52
# 3  Following the demise of Ratan Tata, here are s... 2024-10-09 19:40:00
# 4  Tata Capital-Tata Motors Finance Merger: Throu... 2024-10-14 13:41:19
#
#                                                  url  \
# 0  https://www.forbes.com/sites/johnkang/2024/10/...
# 1  https://www.forbes.com/sites/gloriaharaito/202...
# 2  https://www.livemint.com/opinion/ratan-tata-de...
# 3  https://www.thehindubusinessline.com/multimedi...
# 4  https://www.business-standard.com/companies/ne...
#
#                                              summary  companyName
# 0  Hyundai Motor India managing director Unsoo Ki...  Tata Motors
# 1  Sajjan (left) and Parth Jindal.\nJSW Group\nTh...  Tata Motors
# 2  With the passing of Ratan Naval Tata (1937-202...  Tata Motors
# 3  Following the demise of Ratan Tata, here are s...  Tata Motors
# 4  Through this merger, Tata Capital aims to attr...  Tata Motors

# %%
# Get base url

from urllib.parse import urlparse

def get_base_url(url):
    parsed_url = urlparse(url)
    base_url = f"{parsed_url.scheme}://{parsed_url.netloc}"
    return base_url

# %%
# Applying the function to the 'url' column
df_filtered['source_url'] = df_filtered['url'].apply(get_base_url)

# %%
df_filtered.head()
# Out:
#               source                                            authors  \
# 0             Forbes  John Kang, Forbes Staff, \n John Kang, Forbes ...
# 1             Forbes  Gloria Haraito, Forbes Staff, \n Gloria Harait...
# 2           Livemint                                      George Skaria
# 3       BusinessLine                                                NaN
# 4  Business Standard                                     Dev Chatterjee
#
#                                                title  \
# 0  Hyundai Motor India Shares Slump As Trading Be...
# 1  What’s Driving The Son Of India’s Richest Woma...
# 2   Tata’s next challenge: Leadership void at Trusts
# 3                      Ratan Tata over the years - I
# 4  Tata Capital, Tata Motors Finance merger recei...
#
#                                          description         publishedAt  \
# 0  The South Korean car maker’s $3.3 billion shar... 2024-10-22 16:00:08
# 1  Amid India’s EV push, steel magnate Sajjan Jin... 2024-10-09 22:03:27
# 2  With Ratan Tata’s passing, the lack of a clear... 2024-10-11 05:50:52
# 3  Following the demise of Ratan Tata, here are s... 2024-10-09 19:40:00
# 4  Tata Capital-Tata Motors Finance Merger: Throu... 2024-10-14 13:41:19
#
#                                                  url  \
# 0  https://www.forbes.com/sites/johnkang/2024/10/...
# 1  https://www.forbes.com/sites/gloriaharaito/202...
# 2  https://www.livemint.com/opinion/ratan-tata-de...
# 3  https://www.thehindubusinessline.com/multimedi...
# 4  https://www.business-standard.com/companies/ne...
#
#                                              summary  companyName  \
# 0  Hyundai Motor India managing director Unsoo Ki...  Tata Motors
# 1  Sajjan (left) and Parth Jindal.\nJSW Group\nTh...  Tata Motors
# 2  With the passing of Ratan Naval Tata (1937-202...  Tata Motors
# 3  Following the demise of Ratan Tata, here are s...  Tata Motors
# 4  Through this merger, Tata Capital aims to attr...  Tata Motors
#
#                              source_url
# 0                https://www.forbes.com
# 1                https://www.forbes.com
# 2              https://www.livemint.com
# 3  https://www.thehindubusinessline.com
# 4     https://www.business-standard.com

# %%
df_filtered.head()
# Out:
#               source                                            authors  \
# 0             Forbes  John Kang, Forbes Staff, \n John Kang, Forbes ...
# 1             Forbes  Gloria Haraito, Forbes Staff, \n Gloria Harait...
# 2           Livemint                                      George Skaria
# 3       BusinessLine                                                NaN
# 4  Business Standard                                     Dev Chatterjee
#
#                                                title  \
# 0  Hyundai Motor India Shares Slump As Trading Be...
# 1  What’s Driving The Son Of India’s Richest Woma...
# 2   Tata’s next challenge: Leadership void at Trusts
# 3                      Ratan Tata over the years - I
# 4  Tata Capital, Tata Motors Finance merger recei...
#
#                                          description         publishedAt  \
# 0  The South Korean car maker’s $3.3 billion shar... 2024-10-22 16:00:08
# 1  Amid India’s EV push, steel magnate Sajjan Jin... 2024-10-09 22:03:27
# 2  With Ratan Tata’s passing, the lack of a clear... 2024-10-11 05:50:52
# 3  Following the demise of Ratan Tata, here are s... 2024-10-09 19:40:00
# 4  Tata Capital-Tata Motors Finance Merger: Throu... 2024-10-14 13:41:19
#
#                                                  url  \
# 0  https://www.forbes.com/sites/johnkang/2024/10/...
# 1  https://www.forbes.com/sites/gloriaharaito/202...
# 2  https://www.livemint.com/opinion/ratan-tata-de...
# 3  https://www.thehindubusinessline.com/multimedi...
# 4  https://www.business-standard.com/companies/ne...
#
#                                              summary  companyName  \
# 0  Hyundai Motor India managing director Unsoo Ki...  Tata Motors
# 1  Sajjan (left) and Parth Jindal.\nJSW Group\nTh...  Tata Motors
# 2  With the passing of Ratan Naval Tata (1937-202...  Tata Motors
# 3  Following the demise of Ratan Tata, here are s...  Tata Motors
# 4  Through this merger, Tata Capital aims to attr...  Tata Motors
#
#                              source_url
# 0                https://www.forbes.com
# 1                https://www.forbes.com
# 2              https://www.livemint.com
# 3  https://www.thehindubusinessline.com
# 4     https://www.business-standard.com

# %%
# Remove all rows that contain any null value

# Display the count of null values
print(df_filtered.isnull().sum())

# Remove all rows with any null values
df_cleaned = df_filtered.dropna()

# Display the cleaned DataFrame
print(df_cleaned)
# Out:
# source           0
# authors        216
# title           24
# description      1
# publishedAt      0
# url              0
# summary          0
# companyName      0
# source_url       0
# dtype: int64
#                   source                                            authors  \
# 0                 Forbes  John Kang, Forbes Staff, \n John Kang, Forbes ...
# 1                 Forbes  Gloria Haraito, Forbes Staff, \n Gloria Harait...
# 2               Livemint                                      George Skaria
# 4      Business Standard                                     Dev Chatterjee
# 5               Livemint                                      Nikita Prasad
# ...                  ...                                                ...
# 12142       BusinessLine                        KS Badri Narayanan, Team BL
# 12143       BusinessLine                        KS Badri Narayanan, Team BL
# 12144       BusinessLine                        KS Badri Narayanan, Team BL
# 12145       BusinessLine                        KS Badri Narayanan, Team BL
# 12146       BusinessLine                                            Team BL
#
#                                                    title  \
# 0      Hyundai Motor India Shares Slump As Trading Be...
# 1      What’s Driving The Son Of India’s Richest Woma...
# 2       Tata’s next challenge: Leadership void at Trusts
# 4      Tata Capital, Tata Motors Finance merger recei...
# 5      Ratan Tata passes away at 86: Top business tyc...
# ...                                                  ...
# 12142  Share Market Highlights October 25, 2024: Sens...
# 12143  Closing Bell: Sensex closes 80,369.03, Nifty u...
# 12144  Share Market Highlights October 25, 2024: Sens...
# 12145  Share Market Highlights 29 October 2024: Sense...
# 12146  Stock Market Highlights 30 October 2024: Sense...
#
#                                              description         publishedAt  \
# 0      The South Korean car maker’s $3.3 billion shar... 2024-10-22 16:00:08
# 1      Amid India’s EV push, steel magnate Sajjan Jin... 2024-10-09 22:03:27
# 2      With Ratan Tata’s passing, the lack of a clear... 2024-10-11 05:50:52
# 4      Tata Capital-Tata Motors Finance Merger: Throu... 2024-10-14 13:41:19
# 5      Ratan Tata breathed his last on Wednesday, Oct... 2024-10-09 19:46:32
# ...                                                  ...                 ...
# 12142  Sensex, Nifty updates on October 25, 2024: Dec... 2024-10-25 01:06:01
# 12143  Sensex, Nifty, Share Prices LIVE: Indian equit... 2024-10-29 01:12:10
# 12144  Sensex, Nifty updates on October 25, 2024: Dec... 2024-10-25 01:06:01
# 12145  Sensex, Nifty, Share Prices Highlights: Indian... 2024-10-29 01:12:10
# 12146  Sensex, Nifty, Share Prices : Indian equity be... 2024-10-30 01:10:28
#
#                                                      url  \
# 0      https://www.forbes.com/sites/johnkang/2024/10/...
# 1      https://www.forbes.com/sites/gloriaharaito/202...
# 2      https://www.livemint.com/opinion/ratan-tata-de...
# 4      https://www.business-standard.com/companies/ne...
# 5      https://www.livemint.com/companies/people/rata...
# ...                                                  ...
# 12142  https://www.thehindubusinessline.com/markets/s...
# 12143  https://www.thehindubusinessline.com/markets/c...
# 12144  https://www.thehindubusinessline.com/markets/s...
# 12145  https://www.thehindubusinessline.com/markets/s...
# 12146  https://www.thehindubusinessline.com/markets/s...
#
#                                                  summary  \
# 0      Hyundai Motor India managing director Unsoo Ki...
# 1      Sajjan (left) and Parth Jindal.\nJSW Group\nTh...
# 2      With the passing of Ratan Naval Tata (1937-202...
# 4      Through this merger, Tata Capital aims to attr...
# 5      Ratan Tata passes away:Ratan Tata, chairman em...
# ...                                                  ...
# 12142  <li></li>\nOctober 25, 2024 16:23Currency mark...
# 12143  <li></li>\nOctober 29, 2024 15:57Stock Market ...
# 12144  <li></li>\nOctober 25, 2024 16:23Currency mark...
# 12145  <li></li>\nOctober 29, 2024 16:21Stock Market ...
# 12146  <li></li>\nOctober 30, 2024 16:26Stock market ...
#
#                    companyName                            source_url
# 0                  Tata Motors                https://www.forbes.com
# 1                  Tata Motors                https://www.forbes.com
# 2                  Tata Motors              https://www.livemint.com
# 4                  Tata Motors     https://www.business-standard.com
# 5                  Tata Motors              https://www.livemint.com
# ...                        ...                                   ...
# 12142  Ritco Logistics Limited  https://www.thehindubusinessline.com
# 12143            KIOCL Limited  https://www.thehindubusinessline.com
# 12144            KIOCL Limited  https://www.thehindubusinessline.com
# 12145            KIOCL Limited  https://www.thehindubusinessline.com
# 12146            KIOCL Limited  https://www.thehindubusinessline.com
#
# [11537 rows x 9 columns]

# %%
# Verify the count of null values
df_cleaned.isnull().sum()
# Out:
# source         0
# authors        0
# title          0
# description    0
# publishedAt    0
# url            0
# summary        0
# companyName    0
# source_url     0
# dtype: int64

# %%
# function computes the compound sentiment score for a given piece of text using the VADER sentiment analysis tool,
# which is useful for quickly assessing whether the sentiment of the text is positive, negative, or neutral.

def get_vader_score(text):
    analyzer = SentimentIntensityAnalyzer()
    sentiment = analyzer.polarity_scores(text)
    return sentiment["compound"]

# %%
# Add a new column vader to the DataFrame, which contains the sentiment scores generated by the get_vader_score function.
# The function presumably calculates sentiment analysis using the VADER (Valence Aware Dictionary and sEntiment Reasoner) method,
# which provides a score indicating the sentiment of the text in the content column

df_cleaned['summary_vader'] = df_cleaned['summary'].apply(get_vader_score)

df_cleaned['description_vader'] = df_cleaned['description'].apply(get_vader_score)
# Out:
# /var/folders/3z/qsmfql2d31b5c7fv1rkpfq640000gn/T/ipykernel_5855/3376401207.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['summary_vader'] = df_cleaned['summary'].apply(get_vader_score)
# /var/folders/3z/qsmfql2d31b5c7fv1rkpfq640000gn/T/ipykernel_5855/3376401207.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['description_vader'] = df_cleaned['description'].apply(get_vader_score)

# %%
df_cleaned.head()
# Out:
#               source                                            authors  \
# 0             Forbes  John Kang, Forbes Staff, \n John Kang, Forbes ...
# 1             Forbes  Gloria Haraito, Forbes Staff, \n Gloria Harait...
# 2           Livemint                                      George Skaria
# 4  Business Standard                                     Dev Chatterjee
# 5           Livemint                                      Nikita Prasad
#
#                                                title  \
# 0  Hyundai Motor India Shares Slump As Trading Be...
# 1  What’s Driving The Son Of India’s Richest Woma...
# 2   Tata’s next challenge: Leadership void at Trusts
# 4  Tata Capital, Tata Motors Finance merger recei...
# 5  Ratan Tata passes away at 86: Top business tyc...
#
#                                          description         publishedAt  \
# 0  The South Korean car maker’s $3.3 billion shar... 2024-10-22 16:00:08
# 1  Amid India’s EV push, steel magnate Sajjan Jin... 2024-10-09 22:03:27
# 2  With Ratan Tata’s passing, the lack of a clear... 2024-10-11 05:50:52
# 4  Tata Capital-Tata Motors Finance Merger: Throu... 2024-10-14 13:41:19
# 5  Ratan Tata breathed his last on Wednesday, Oct... 2024-10-09 19:46:32
#
#                                                  url  \
# 0  https://www.forbes.com/sites/johnkang/2024/10/...
# 1  https://www.forbes.com/sites/gloriaharaito/202...
# 2  https://www.livemint.com/opinion/ratan-tata-de...
# 4  https://www.business-standard.com/companies/ne...
# 5  https://www.livemint.com/companies/people/rata...
#
#                                              summary  companyName  \
# 0  Hyundai Motor India managing director Unsoo Ki...  Tata Motors
# 1  Sajjan (left) and Parth Jindal.\nJSW Group\nTh...  Tata Motors
# 2  With the passing of Ratan Naval Tata (1937-202...  Tata Motors
# 4  Through this merger, Tata Capital aims to attr...  Tata Motors
# 5  Ratan Tata passes away:Ratan Tata, chairman em...  Tata Motors
#
#                           source_url  summary_vader  description_vader
# 0             https://www.forbes.com         0.0000             0.2960
# 1             https://www.forbes.com         0.7783             0.4767
# 2           https://www.livemint.com         0.0772             0.6486
# 4  https://www.business-standard.com         0.4939             0.4939
# 5           https://www.livemint.com        -0.3182            -0.1779

# %%
df_cleaned.shape
# Out:
# (11537, 11)

# %%
# Save the pre-processed file
df_cleaned.to_csv('../Dataset/newsapi/preprocessed/company_news_preprocessed.csv', index=False)
